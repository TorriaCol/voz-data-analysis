# %%
import os
import sys

sys.path.append(os.path.abspath(".."))

from data_tools import available_dates
from data_tools import my_setup
from data_tools import deployment_sets as sets

# === USER INPUTS ===
path = my_setup.raw_2025data_path()
files = sets.files_2025()
datetime_col = "date_time"
start_date = "2025-06-02"
end_date = "2025-12-31"

available_dates.to_spreadsheet(path,files,datetime_col,start_date,end_date)
# Out:
# Saved results to ../reference_files/2025rawdata/present_dates.xlsx
